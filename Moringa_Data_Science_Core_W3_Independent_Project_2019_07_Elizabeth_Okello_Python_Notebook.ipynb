# %% [markdown]
# <a href="https://colab.research.google.com/github/EOKELLO/IP-WEEK1-CORE/blob/master/Moringa_Data_Science_Core_W3_Independent_Project_2019_07_Elizabeth_Okello_Python_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Research Question**

# %% [markdown]
# # **Metric for success**

# %% [markdown]
# successfully plotting the univariate and bivariate plots
# successfully choosing the best sampling method for our case study
# being able to come to a conclusion of whether to reject or fail to reject my hypothesis

# %% [markdown]
# # **The context**

# %% [markdown]
# The dataset enables us to understand the electric car usage in the city of paris.
# We specifically want to investigate the car-sharing service company over a claim about the blue cars from the provided Autolib dataset.

# %% [markdown]
# # Experimental design

# %% [markdown]
# Load the data in a pandas data frame
# Clean the data by finding and dealing with outliers, anomalies, and missing data within the dataset if any.
# Plot appropriate univariate and bivariate summaries as we record our observations and insights picked from the plots.
# choose the best sampling technique
# Implement the solution by performing hypothesis testing.
# Challenge our solution by providing insights on how we can make improvements.

# %% [markdown]
# # **Appropriateness of the data**

# %%
#the data is appropriate as it contains attributes that can help us answer our research question.
#the quantity

# %%
#we load important libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt# for visualization
import seaborn as sns#for visualization

# %%
#we load the dataset into to the notebook
url='http://bit.ly/DSCoreAutolibDataset'
data=pd.read_csv(url)
data.head()
# Out:
#    Postal code      date  ...  Slots_freed_sum  Slots_taken_sum
# 0        75001  1/1/2018  ...               22               20
# 1        75001  1/2/2018  ...               23               22
# 2        75001  1/3/2018  ...               27               27
# 3        75001  1/4/2018  ...               25               21
# 4        75001  1/5/2018  ...               18               20
#
# [5 rows x 13 columns]

# %%
#we get the size of our records
data.shape
# Out:
# (16085, 13)

# %%
#check for missing values
data.isnull().sum()
#the below dataset has no missing values as shown below.
# Out:
# Postal code               0
# date                      0
# n_daily_data_points       0
# dayOfWeek                 0
# day_type                  0
# BlueCars_taken_sum        0
# BlueCars_returned_sum     0
# Utilib_taken_sum          0
# Utilib_returned_sum       0
# Utilib_14_taken_sum       0
# Utilib_14_returned_sum    0
# Slots_freed_sum           0
# Slots_taken_sum           0
# dtype: int64

# %%
#we check the data types in the dataset
data.dtypes
# Out:
# Postal code                int64
# date                      object
# n_daily_data_points        int64
# dayOfWeek                  int64
# day_type                  object
# BlueCars_taken_sum         int64
# BlueCars_returned_sum      int64
# Utilib_taken_sum           int64
# Utilib_returned_sum        int64
# Utilib_14_taken_sum        int64
# Utilib_14_returned_sum     int64
# Slots_freed_sum            int64
# Slots_taken_sum            int64
# dtype: object

# %% [markdown]
# # **Checking for anomalies**

# %%
#we check for outliers in the columns that interest us which is the bluecars and the day_type

sns.boxplot(data['BlueCars_taken_sum'],showmeans=True)#we use  this code to check for anomalies in the bluecars taken column
#there is a presence of anomalies in our column but we shall not drop them as from the trends we may just assume that their presence
#points towards them being a preference of many and not necessarily an out of range measure .

# %%
#we can check the descriptive statistics of our dataset by using the describe method
#from our descriptive statisctics we can see that yes indeed blue cars are the most used in the city of paris as it has the highest mean compared to other car types
#max value for the blue cars is also way higher than the utilib and utilib 14 types
data.describe()
# Out:
#         Postal code  n_daily_data_points  ...  Slots_freed_sum  Slots_taken_sum
# count  16085.000000         16085.000000  ...     16085.000000     16085.000000
# mean   88791.293876          1431.330619  ...        22.629033        22.629282
# std     7647.342000            33.212050  ...        52.120263        52.146030
# min    75001.000000          1174.000000  ...         0.000000         0.000000
# 25%    91330.000000          1439.000000  ...         0.000000         0.000000
# 50%    92340.000000          1440.000000  ...         0.000000         0.000000
# 75%    93400.000000          1440.000000  ...         5.000000         5.000000
# max    95880.000000          1440.000000  ...       360.000000       359.000000
#
# [8 rows x 11 columns]

# %%
#we now want to make plots to help us understand our dataset better.
#we begin by performing univariate analysis
data['BlueCars_taken_sum'].hist()

# %%
data['BlueCars_returned_sum'].hist()

# %%
data['BlueCars_taken_sum'].value_counts().head(10).plot.bar()

# %%
data['Utilib_taken_sum'].value_counts().head(10).plot.bar()

# %%
data['Utilib_14_taken_sum'].value_counts().head(10).plot.bar()

# %%
#we then proceed to do a bivariate analysis
#here we want to check how the blue cars compair with other attributes present in out dataset
#we plot how blue cars compare with the day type
sns.catplot(x="day_type", y="BlueCars_taken_sum", data=data)
plt.xticks(rotation = 90)
plt.title('day_type vs BlueCars_taken_sum')
# Out:
# Text(0.5, 1.0, 'day_type vs BlueCars_taken_sum')

# %%
sns.catplot(x="day_type", y="Utilib_taken_sum", data=data)
plt.xticks(rotation = 90)
plt.title('day_type vs Utilib_taken_sum')
# Out:
# Text(0.5, 1.0, 'day_type vs Utilib_taken_sum')

# %%
sns.catplot(x="dayOfWeek", y="BlueCars_taken_sum", data=data)
plt.xticks(rotation = 90)
plt.title('dayOfWeek vs BlueCars_taken_sum')
# Out:
# Text(0.5, 1.0, 'dayOfWeek vs BlueCars_taken_sum')

# %%
plt.figure(figsize=(8, 6))

sns.pairplot(data, diag_kind='kde')

# %%
#we now proceed to choose the sampling methods to apply but first lets pick the appropriate subset of data we need to answer test our hypothesis.
#Selecting the features we want from our Dataset

[ ]
# Since we want to cluster our dataset depending on day_type, we are going to extract the longitude and latitude and use them as our input while clustering
# To achieve this we will use panda's method .iloc to slice the columns we want from the dataset.
# The first argument of this method identifies the rows we want to keep
# The second - the columns
# In our case, we want to keep all rows and the 4 and 5 colummn.


x = data.iloc[:, 4:6]

# Check if we got the 4 and  column
x.head()
# Out:
#   day_type  BlueCars_taken_sum
# 0  weekday                 110
# 1  weekday                  98
# 2  weekday                 138
# 3  weekday                 104
# 4  weekday                 114

# %%
#out test is a one tailed test
#its a right tailed test
